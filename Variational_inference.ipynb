# %% [markdown]
# # Variational Inference
#
# resources:
# - https://www.youtube.com/watch?v=VWb0ZywWpqc&ab_channel=RAIL
# -
#
# gloassary:
# - latent variable models
# - generative models
# - evidence lower bound (elbo) aka variational lower bound
# - expected log liklihood
# - approximate bayesian inference via variational ifnerence
# - training latent variable models with MLE is intractable -> use expected log liklihood
#
# deep latent variable models :
# - gans
# - vaes
# - normalizing flow models
# - diffusion models
#
# dl without latent variables
# - autoregressive models

# %% [markdown]
# ![image.png](attachment:5ceb38dd-bf03-4592-a03f-68cc68daea8b.png)
#
# - sampling p(x)? -> sample p(z) and push through network to get parameters then sample Normal
# - evaluating liklihood of sample xi? -> sample a bunch of z and do following integral: $p(x) = \int p(x|z)p(z)dz$
